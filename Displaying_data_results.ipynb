# %%
# %pip install flask plotly
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plot_likert

file_path = "./data/wellbeing_survey.csv"

try:
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Display the first 10 rows of the data to check format, DEBUG
    #print("Survey Results (first 10 rows):")
    #print(df.head(10))

    # Check the unique values to identify responses
    questions = [
        "I felt happy.",
        "I felt engaged.",
        "I felt comfortable.",
        "I felt safe and secure.",
        "I enjoyed the company of other people.",
        "I talked to other people.",
    ]

    # Get relevant columns for Likert scale analysis
    likert_data = df[questions]
    unique_responses = pd.unique(likert_data.values.ravel('K'))
    print("Unique responses found in the data:", unique_responses) #Debug

except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found.") 
except pd.errors.EmptyDataError:
    print("Error: The CSV file is empty.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Unique responses found in the data: ['Strongly disagree' 'Disagree' 'Strongly agree'
#  'Neither agree nor disagree' 'Agree']

# %%
# use agree5 to plot the data
display(likert_data)
myscale = ("Strongly agree", "Agree", "Neither agree nor disagree", "Disagree", "Strongly disagree")
plot_likert.plot_likert(likert_data, myscale, plot_percentage=True, figsize=(11,2));
# Out:
#                  I felt happy.             I felt engaged.  \
# 0            Strongly disagree           Strongly disagree
# 1                     Disagree  Neither agree nor disagree
# 2               Strongly agree              Strongly agree
# 3   Neither agree nor disagree  Neither agree nor disagree
# 4            Strongly disagree                       Agree
# 5               Strongly agree              Strongly agree
# 6   Neither agree nor disagree  Neither agree nor disagree
# 7                        Agree                       Agree
# 8                     Disagree                    Disagree
# 9                        Agree           Strongly disagree
# 10                       Agree           Strongly disagree
# 11           Strongly disagree           Strongly disagree
# 12              Strongly agree              Strongly agree
# 13  Neither agree nor disagree  Neither agree nor disagree
# 14                       Agree                       Agree
# ...

# %%
# with percentages for each level
plot_likert.plot_likert(likert_data, myscale, plot_percentage=True,
                        bar_labels=True, bar_labels_color="snow", colors=plot_likert.colors.default_with_darker_neutral, figsize=(11,2));
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]

# %% [markdown]
# https://github.com/nmalkin/plot-likert
# https://github.com/nmalkin/plot-likert/blob/master/docs/example.ipynb
# https://github.com/nmalkin/plot-likert/blob/master/docs/guide.ipynb

# %%
import pandas as pd
import plot_likert
import matplotlib.pyplot as plt
import os

file_path = "./data/wellbeing_survey.csv"

try:
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Check the unique values to identify responses
    questions = [
        "I felt happy.",
        "I felt engaged.",
        "I felt comfortable.",
        "I felt safe and secure.",
        "I enjoyed the company of other people.",
        "I talked to other people.",
    ]

    # Get relevant columns for Likert scale analysis
    likert_data = df[questions]
    unique_responses = pd.unique(likert_data.values.ravel('K'))
    print("Unique responses found in the data:", unique_responses)

    # Plot the Likert scale
    myscale = ("Strongly agree", "Agree", "Neither agree nor disagree", "Disagree", "Strongly disagree")
    fig, ax = plt.subplots(figsize=(13, 3))
    plot_likert.plot_likert(likert_data, myscale, plot_percentage=True, ax=ax)

    # Adjust layout to prevent cutoff and add padding
    plt.tight_layout(pad=1)

    # Save the plot as likert_plot.png in the 'static' folder
    static_folder = 'static'
    if not os.path.exists(static_folder):
        os.makedirs(static_folder)
    
    plot_path = os.path.join(static_folder, 'likert_plot.png')
    plt.savefig(plot_path)
    print(f"Likert plot saved as {plot_path}")

except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found.") 
except pd.errors.EmptyDataError:
    print("Error: The CSV file is empty.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Unique responses found in the data: ['Strongly disagree' 'Disagree' 'Strongly agree'
#  'Neither agree nor disagree' 'Agree']
# Likert plot saved as static/likert_plot.png
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]
